# %%
# %pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in c:\users\youssouf djire\appdata\local\programs\python\python311\lib\site-packages (2.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kafka import KafkaProducer

producer = KafkaProducer(bootstrap_servers="localhost:9092")
producer.send("test_topic", b"hello from jupyter")
producer.flush()
print("Sent from Jupyter")
# Out:
# Sent from Jupyter ✅

# %%
from kafka import KafkaProducer
producer = KafkaProducer(bootstrap_servers="localhost:9092")
producer.send("test_topic", b"message test: spark is reading kafka")
producer.flush()
print("Sent to Kafka")
# Out:
# Sent to Kafka

# %%
producer.send("test_topic", b"spark reads kafka now")
producer.flush()
